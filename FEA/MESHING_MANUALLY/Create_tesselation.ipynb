# %% [markdown]
# Creation of a .msh file from a .stl file using gmsh. The first step is to reconstruct the parametric model form the stl file and them mesh it. With that regard, I beleive it is better to start from an stp file and not from a stl file.

# %% [markdown]
# Generate mesh from stp file using gmsh. The problem with this following code being that the tesselation size is not controlled.

# %%
import gmsh
import sys

# ========== USER SETTINGS ==========
step_file = "Living_hinge_1.step"    # Your STEP file
mesh_file = "Living_hinge_1.msh"
target_element_size = 0.01     # Max element size
visualize = True
# ===================================

gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.add("MeshFromSTEP")

# Load STEP file
gmsh.option.setString("Geometry.OCCTargetUnit", "M")  # or "MM" depending on model units
gmsh.model.occ.importShapes(step_file)
gmsh.model.occ.synchronize()

# Disable curvature-based sizing and others that may override global size
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)

# Apply mesh size to all points explicitly
points = gmsh.model.getEntities(dim=0)
for p in points:
    gmsh.model.mesh.setSize([p], target_element_size)

# Add physical groups (optional but recommended for solvers)
surfaces = gmsh.model.getEntities(dim=2)
volumes = gmsh.model.getEntities(dim=3)

if surfaces:
    surface_tags = [s[1] for s in surfaces]
    gmsh.model.addPhysicalGroup(2, surface_tags)
    gmsh.model.setPhysicalName(2, 1, "walls")

if volumes:
    volume_tags = [v[1] for v in volumes]
    gmsh.model.addPhysicalGroup(3, volume_tags)
    gmsh.model.setPhysicalName(3, 2, "domain")

# Generate 3D mesh
gmsh.model.mesh.generate(3)

# Save mesh
gmsh.write(mesh_file)

# GUI view
if visualize:
    gmsh.fltk.run()

gmsh.finalize()
# Out:
# Info    :  - Label 'Shapes/Living_hinge_1 v1' (3D)
# Info    :  - Color (0.627451, 0.627451, 0.627451) (3D & Surfaces)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Circle)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Circle)
# Info    : [ 20%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 7 (Circle)
# Info    : [ 30%] Meshing curve 8 (Line)
# Info    : [ 30%] Meshing curve 9 (Line)
# Info    : [ 40%] Meshing curve 10 (Line)
# Info    : [ 40%] Meshing curve 11 (Line)
# Info    : [ 40%] Meshing curve 12 (Line)
# Info    : [ 50%] Meshing curve 13 (Circle)
# Info    : [ 50%] Meshing curve 14 (Circle)
# Info    : [ 50%] Meshing curve 15 (Line)
# Info    : [ 60%] Meshing curve 16 (Line)
# Info    : [ 60%] Meshing curve 17 (Circle)
# Info    : [ 60%] Meshing curve 18 (Line)
# Info    : [ 70%] Meshing curve 19 (Line)
# Info    : [ 70%] Meshing curve 20 (Circle)
# Info    : [ 70%] Meshing curve 21 (Line)
# Info    : [ 80%] Meshing curve 22 (Line)
# Info    : [ 80%] Meshing curve 23 (Line)
# Info    : [ 80%] Meshing curve 24 (Line)
# Info    : [ 90%] Meshing curve 25 (Line)
# Info    : [ 90%] Meshing curve 26 (Line)
# Info    : [ 90%] Meshing curve 27 (Line)
# Info    : [100%] Meshing curve 28 (Line)
# Info    : [100%] Meshing curve 29 (Line)
# Info    : [100%] Meshing curve 30 (Line)
# Info    : Done meshing 1D (Wall 0.00302117s, CPU 0.01273s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Cylinder, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 4 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 5 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0100261s, CPU 0.042902s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 30 nodes...
# Info    : Done tetrahedrizing 38 nodes (Wall 0.00100333s, CPU 0.001284s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00269029s, CPU 0.003432s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 3.12331 (nodes removed 0 0)
# Info    : 3D refinement terminated (30 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 6 nodes could not be inserted
# Info    :  - 50 tetrahedra created in 2.2291e-05 sec. (2243054 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.00480563s, CPU 0.009374s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 2.14167e-05) with worst = 0.0100929 / average = 0.171111:
# Info    : 0.00 < quality < 0.10 :        30 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :        12 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         8 elements
# Info    : 0.60 < quality < 0.70 :         0 elements
# Info    : 0.70 < quality < 0.80 :         0 elements
# Info    : 0.80 < quality < 0.90 :         0 elements
# Info    : 0.90 < quality < 1.00 :         0 elements
# Info    : 9 edge swaps, 0 node relocations (volume = 2.14167e-05): worst = 0.0100929 / average = 0.189649 (Wall 0.000344834s, CPU 0.000672s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        25 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :        12 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         8 elements
# Info    : 0.60 < quality < 0.70 :         0 elements
# Info    : 0.70 < quality < 0.80 :         0 elements
# Info    : 0.80 < quality < 0.90 :         0 elements
# Info    : 0.90 < quality < 1.00 :         0 elements
# Info    : Done optimizing mesh (Wall 0.000851416s, CPU 0.001508s)
# Info    : 30 nodes 159 elements
# Info    : Writing 'Living_hinge_1.msh'...
# Info    : Done writing 'Living_hinge_1.msh'
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : MacOSARM-sdk
# Build date    : 20240524
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] MathEx[contrib] Med Mesh Metis[contrib] Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] TouchBar Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.17.4 (real arithmtic)
# OCC version   : 7.7.2
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %% [markdown]
# Control tesselation size using gmsh.

# %%
import gmsh
import sys
import numpy as np

# Initialize Gmsh
gmsh.initialize()

# Load the STEP file (replace 'input.stp' with your STEP file path)
gmsh.model.occ.importShapes("Living_hinge_1.step")

# Synchronize the geometry to update the model
gmsh.model.occ.synchronize()

# Get all volumes in the model
volumes = gmsh.model.getEntities(dim=3)

# Define physical groups for all volumes (optional, for solver compatibility)
for i, vol in enumerate(volumes):
    gmsh.model.addPhysicalGroup(vol[0], [vol[1]], name=f"volume_{i+1}")

# Define a distance-based mesh size field
# Mesh size will be smaller near the origin (0,0,0) and larger farther away
field_id = 1
gmsh.model.mesh.field.add("Distance", field_id)
gmsh.model.mesh.field.setNumbers(field_id, "PointsList", [1])  # Reference point at origin
gmsh.model.mesh.field.setNumber(field_id, "Sampling", 100)

# Define a math evaluation field to compute mesh size based on distance
field_id_size = 2
gmsh.model.mesh.field.add("MathEval", field_id_size)
gmsh.model.mesh.field.setString(field_id_size, "F", "0.01 + 0.1 * F1")  # Min size 0.01, increases with distance

# Set the minimum field as the background mesh field
gmsh.model.mesh.field.add("Min", 3)
gmsh.model.mesh.field.setNumbers(3, "FieldsList", [field_id_size])
gmsh.model.mesh.field.setAsBackgroundMesh(3)

# Set global mesh parameters
gmsh.option.setNumber("Mesh.MeshSizeMin", 0.0003)  # Minimum element size
gmsh.option.setNumber("Mesh.MeshSizeMax", 0.01)   # Maximum element size
gmsh.option.setNumber("Mesh.Algorithm", 5)       # Delaunay for 3D meshing
gmsh.option.setNumber("Mesh.Format", 1)          # MSH format (version 2 ASCII)

# Generate the 3D mesh
gmsh.model.mesh.generate(3)

# Save the mesh to a file
gmsh.write("cylinder.msh")

# Optional: Launch Gmsh GUI to visualize the mesh
if '-nopopup' not in sys.argv:
    gmsh.fltk.run()

# Finalize Gmsh
gmsh.finalize()
# Out:
# Info    :  - Label 'Shapes/Living_hinge_1 v1' (3D)
# Info    :  - Color (0.627451, 0.627451, 0.627451) (3D & Surfaces)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Circle)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 5 (Circle)
# Info    : [ 20%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 7 (Circle)
# Info    : [ 30%] Meshing curve 8 (Line)
# Info    : [ 30%] Meshing curve 9 (Line)
# Info    : [ 40%] Meshing curve 10 (Line)
# Info    : [ 40%] Meshing curve 11 (Line)
# Info    : [ 40%] Meshing curve 12 (Line)
# Info    : [ 50%] Meshing curve 13 (Circle)
# Info    : [ 50%] Meshing curve 14 (Circle)
# Info    : [ 50%] Meshing curve 15 (Line)
# Info    : [ 60%] Meshing curve 16 (Line)
# Info    : [ 60%] Meshing curve 17 (Circle)
# Info    : [ 60%] Meshing curve 18 (Line)
# Info    : [ 70%] Meshing curve 19 (Line)
# Info    : [ 70%] Meshing curve 20 (Circle)
# Info    : [ 70%] Meshing curve 21 (Line)
# Info    : [ 80%] Meshing curve 22 (Line)
# Info    : [ 80%] Meshing curve 23 (Line)
# Info    : [ 80%] Meshing curve 24 (Line)
# Info    : [ 90%] Meshing curve 25 (Line)
# Info    : [ 90%] Meshing curve 26 (Line)
# Info    : [ 90%] Meshing curve 27 (Line)
# Info    : [100%] Meshing curve 28 (Line)
# Info    : [100%] Meshing curve 29 (Line)
# Info    : [100%] Meshing curve 30 (Line)
# Info    : Done meshing 1D (Wall 0.00522787s, CPU 0.002944s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Cylinder, Delaunay)
# Info    : [ 10%] Meshing surface 2 (Cylinder, Delaunay)
# Info    : [ 20%] Meshing surface 3 (Plane, Delaunay)
# Info    : [ 30%] Meshing surface 4 (Cylinder, Delaunay)
# Info    : [ 40%] Meshing surface 5 (Cylinder, Delaunay)
# Info    : [ 50%] Meshing surface 6 (Plane, Delaunay)
# Info    : [ 60%] Meshing surface 7 (Plane, Delaunay)
# Info    : [ 60%] Meshing surface 8 (Plane, Delaunay)
# Info    : [ 70%] Meshing surface 9 (Plane, Delaunay)
# Info    : [ 80%] Meshing surface 10 (Plane, Delaunay)
# Info    : [ 90%] Meshing surface 11 (Plane, Delaunay)
# Info    : [100%] Meshing surface 12 (Plane, Delaunay)
# Info    : Done meshing 2D (Wall 0.0278382s, CPU 0.024976s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 210 nodes...
# Info    : Done tetrahedrizing 218 nodes (Wall 0.00220683s, CPU 0.001733s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00488079s, CPU 0.00383s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 0.82925 (nodes removed 0 0)
# Info    : 3D refinement terminated (210 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 559 tetrahedra created in 1.2542e-05 sec. (44570227 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.0115411s, CPU 0.008332s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 2.14369e-05) with worst = 0.0337336 / average = 0.65635:
# Info    : 0.00 < quality < 0.10 :        37 elements
# Info    : 0.10 < quality < 0.20 :        10 elements
# Info    : 0.20 < quality < 0.30 :         3 elements
# Info    : 0.30 < quality < 0.40 :         9 elements
# Info    : 0.40 < quality < 0.50 :        30 elements
# Info    : 0.50 < quality < 0.60 :        63 elements
# Info    : 0.60 < quality < 0.70 :       126 elements
# Info    : 0.70 < quality < 0.80 :       154 elements
# Info    : 0.80 < quality < 0.90 :        84 elements
# Info    : 0.90 < quality < 1.00 :        43 elements
# Info    : 20 edge swaps, 0 node relocations (volume = 2.14369e-05): worst = 0.0337336 / average = 0.665643 (Wall 0.000688542s, CPU 0.000491s)
# Info    : 28 edge swaps, 0 node relocations (volume = 2.14369e-05): worst = 0.0337336 / average = 0.673684 (Wall 0.00106188s, CPU 0.000868s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        22 elements
# Info    : 0.10 < quality < 0.20 :         6 elements
# Info    : 0.20 < quality < 0.30 :         2 elements
# Info    : 0.30 < quality < 0.40 :        12 elements
# Info    : 0.40 < quality < 0.50 :        31 elements
# Info    : 0.50 < quality < 0.60 :        55 elements
# Info    : 0.60 < quality < 0.70 :       120 elements
# Info    : 0.70 < quality < 0.80 :       161 elements
# Info    : 0.80 < quality < 0.90 :        86 elements
# Info    : 0.90 < quality < 1.00 :        42 elements
# Info    : Done optimizing mesh (Wall 0.00148425s, CPU 0.001288s)
# Info    : 210 nodes 1083 elements
# Info    : Writing 'cylinder.msh'...
# Info    : Done writing 'cylinder.msh'
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : MacOSARM-sdk
# Build date    : 20240524
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] MathEx[contrib] Med Mesh Metis[contrib] Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] TouchBar Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.17.4 (real arithmtic)
# OCC version   : 7.7.2
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %% [markdown]
# File conversion of a .msh format into a more readable abaqus format : .inp

# %%
import meshio

mesh = meshio.read("Living_hinge_1.msh")
meshio.write("Living_hinge_1.inp", mesh)

# %%
def extract_inp_sections_to_inp(input_path, output_path):
    
    with open(input_path, 'r') as f:
        lines = f.readlines()

    writing_nodes = False
    writing_elements = False
    nodes = []
    elements = []
    node_header = ""
    element_header = ""

    for line in lines:
        stripped = line.strip()
        upper = stripped.upper()

        if upper.startswith("*NODE"):
            writing_nodes = True
            writing_elements = False
            node_header = line.rstrip()
            continue
        elif upper.startswith("*ELEMENT"):
            writing_elements = True
            writing_nodes = False
            element_header = line.rstrip()
            continue
        elif upper.startswith("*ELSET"):  # stop reading at *ELSET or similar
            break

        if writing_nodes and stripped and not stripped.startswith("*"):
            nodes.append(line.rstrip())
        elif writing_elements and stripped and not stripped.startswith("*"):
            elements.append(line.rstrip())

    with open(output_path, 'w') as f:
        if node_header:
            f.write(f"{node_header}\n")
            for n in nodes:
                f.write(f"\t{n}\n")  # tab before each value line
        if element_header:
            f.write(f"{element_header}\n")
            for e in elements:
                f.write(f"\t{e}\n")  # tab before each value line

    print(f"Extracted .inp written to: {output_path}")

# %%
extract_inp_sections_to_inp('cylinder.inp', 'cylinder2.msh')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 extract_inp_sections_to_inp('cylinder.inp', 'cylinder2.msh')
#
# Cell In[4], line 3, in extract_inp_sections_to_inp(input_path, output_path)
#       1 def extract_inp_sections_to_inp(input_path, output_path):
# ----> 3     with open(input_path, 'r') as f:
#       4         lines = f.readlines()
#       6     writing_nodes = False
#
# File ~/miniconda3/envs/CALCULIX/lib/python3.11/site-packages/IPython/core/interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cylinder.inp'
